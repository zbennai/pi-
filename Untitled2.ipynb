# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import nltk
import io

LM_list = pd.read_csv("c:\\Users\\famille\\Downloads\\lexiqueLM.csv",sep = ';')
LM_positive = [pos.lower() for pos in LM_list['POSITIVE'].dropna(axis=0)]
LM_negative = [pos.lower() for pos in LM_list['NEGATIVE'].dropna(axis=0)]

with io.open("c:\\Users\\famille\\Downloads\\AAL-10k-2016.txt", 'r',encoding='utf8') as file:
    text = file.read().replace('\n', ' ')

text_LM = nltk.word_tokenize(text)
nb_pos = [word for word in text_LM if word in LM_positive]
nb_neg = [word for word in text_LM if word in LM_negative]
if (len(nb_pos)+len(nb_neg)) != 0:
    Sent_LM = ((len(nb_pos)-len(nb_neg))/(len(nb_pos)+len(nb_neg)))
else:
    Sent_LM = 0

print("NB POS : ", len(nb_pos))
print("NB NEG : ", len(nb_neg))
print("SCORE : ", Sent_LM)
# Out:
# NB POS :  342
# NB NEG :  112
# SCORE :  0.5066079295154186

# %%
#python -m pip install bs4
##python-m pip install requests

from datetime import datetime
from bs4 import BeautifulSoup
import requests 
import time 
import re

with open("c:\\Users\\famille\\Downloads\\cik.txt", 'r') as file:
    liste = file.read().replace('\n', ' ')

CIK_list= nltk.word_tokenize(liste)
CIK = "0000320193"
for element in CIK_list:
    print (element)
    CIK = element
    url = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s"%CIK
    content = requests.get(url)
    pageHTML = BeautifulSoup(content.content,'html.parser')
    txt_ = pageHTML.find(class_ = "blueRow")
    print(txt_)




#MONGODB
# enregistrer dans un csv tous les CIK de tous els 10K
# ensuite on enregistre tous les fichiers TXT qui 

# TICKER , date , fling , url , document
# Out:
# 0001489393
# <tr class="blueRow">
# <td nowrap="nowrap">4</td>
# <td nowrap="nowrap"><a href="/Archives/edgar/data/1489393/000156218019005407/0001562180-19-005407-index.htm" id="documentsbutton"> Documents</a></td>
# <td class="small">Statement of changes in beneficial ownership of securities<br>Acc-no: 0001562180-19-005407 Size: 11 KB            </br></td>
# <td>2019-11-08</td>
# <td></td>
# </tr>
# 0000004962
# <tr class="blueRow">
# <td nowrap="nowrap">3</td>
# <td nowrap="nowrap"><a href="/Archives/edgar/data/4962/000112760219032740/0001127602-19-032740-index.htm" id="documentsbutton"> Documents</a></td>
# <td class="small">Initial statement of beneficial ownership of securities<br>Acc-no: 0001127602-19-032740 Size: 6 KB            </br></td>
# <td>2019-11-14</td>
# <td></td>
# </tr>
# 0000732712
# <tr class="blueRow">
# <td nowrap="nowrap">424B2</td>
# ...

# %%
from datetime import datetime
from bs4 import BeautifulSoup
import requests 
import time 
import re

with open("c:\\Users\\famille\\Downloads\\cik.txt", 'r') as file:
    liste = file.read().replace('\n', ' ')

CIK = "0000320193"

url = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=10-k"%CIK
content = requests.get(url)
pageHTML = BeautifulSoup(content.content,'html.parser')
txt_ = pageHTML.find(class_ = "tableFile2")
t = str(txt_)
f= nltk.word_tokenize(t)
i=0
j=0
compt=[]
adresse2 =[]
for link in pageHTML.find_all("a"):
    print(link.get("href"))
    adresse2.append("https://www.sec.gov")
    

for element in f:
    if "index.htm" in element:
        compt.append(i)
        i+=1
    else :
        i+=1
adresse =[]
for j in range(len(compt)):
    print("https://www.sec.gov"+ str(f[compt[j]]))
    adresse.append("https://www.sec.gov"+ str(f[compt[j]]))
# Out:
# /index.htm
# /cgi-bin/browse-edgar?action=getcurrent
# javascript:history.back()
# /index.htm
# /cgi-bin/browse-edgar?action=getcompany&CIK=0000320193&type=10-k%25&dateb=&owner=include&count=100&output=xml
# /index.htm
# /edgar/searchedgar/webusers.htm
# /edgar/searchedgar/companysearch.html
# /cgi-bin/browse-edgar?action=getcompany&CIK=0000320193&owner=include&count=40
# /cgi-bin/browse-edgar?action=getcompany&SIC=3571&owner=include&count=40
# /cgi-bin/browse-edgar?action=getcompany&State=CA&owner=include&count=40
# /cgi-bin/own-disp?action=getissuer&CIK=0000320193
# /cgi-bin/browse-edgar?action=getcompany&CIK=0000320193&type=10-k%25&dateb=&owner=include&start=0&count=40&output=atom
# /Archives/edgar/data/320193/000032019319000119/0000320193-19-000119-index.htm
# /cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-19-000119&xbrl_type=v
# /cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=include&count=40
# ...

# %%
url = adresse[1]
print(url)
content = requests.get(url)
pageHTML = BeautifulSoup(content.content,'html.parser')
txt_ = pageHTML.find(class_ = "tableFile")
txt = str(txt_)
print(txt)
t_str= nltk.word_tokenize(txt)
i=0
j=0
compteur=[]

for word in t_str:
    if "Archives" in word:
        compteur.append(i)
        i+=1
    else :
        i+=1
finalAdress=[]        
for j in range(len(compteur)):
    print("https://www.sec.gov"+ str(t_str[compteur[j]]))
    finalAdress.append("https://www.sec.gov"+ str(t_str[compteur[j]]))
# Out:
# https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/0000320193-18-000145-index.htm
# <table class="tableFile" summary="Document Format Files">
# <tr>
# <th scope="col" style="width: 5%;"><acronym title="Sequence Number">Seq</acronym></th>
# <th scope="col" style="width: 40%;">Description</th>
# <th scope="col" style="width: 20%;">Document</th>
# <th scope="col" style="width: 10%;">Type</th>
# <th scope="col">Size</th>
# </tr>
# <tr>
# <td scope="row">1</td>
# <td scope="row">10-K</td>
# <td scope="row"><a href="/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm">a10-k20189292018.htm</a></td>
# <td scope="row">10-K</td>
# <td scope="row">2405889</td>
# </tr>
# <tr class="blueRow">
# <td scope="row">2</td>
# <td scope="row">EXHIBIT 10.17</td>
# <td scope="row"><a href="/Archives/edgar/data/320193/000032019318000145/a10-kexhibit10172018.htm">a10-kexhibit10172018.htm</a></td>
# <td scope="row">EX-10.17</td>
# <td scope="row">54096</td>
# </tr>
# <tr>
# ...

# %%
url = "https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm"
print(url)
content = requests.get(url)
pageHTML = BeautifulSoup(content.content,'html.parser')
t = pageHTML.find(class_ = "text")
txt = str(pageHTML)
t_str= nltk.word_tokenize(txt)

i=0
j=0
compteur=[]
for word in t_str:
    if "Archives" in word:
        compteur.append(i)
        i+=1
    else :
        i+=1
finalAdress=[]        
for j in range(len(compteur)):
    print("https://www.sec.gov"+ str(t_str[compteur[j]]))
    finalAdress.append("https://www.sec.gov"+ str(t_str[compteur[j]]))
# Out:
# https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312514228798/d739696dex31.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000162828016022047/exhbit3212-15x16.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000110465907006648/a07-2749_1ex4d1.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312513179942/d527270dex41.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312513199324/d529124dex41.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312514184969/d721207dex41.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312514406296/d816414dex41.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312515039270/d868302dex41.htm
# https://www.sec.gov//www.sec.gov/Archives/edgar/data/320193/000119312515186064/d923398dex41.htm
# ...

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

p1 = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start="
p2 = "&count=100"
def get_pages(p1, nb, p2):
    pages = []
    for i in range(0,nb+1):
        j = p1 + str(i*100) + p2
        pages.append(j)
    return pages
pages = get_pages(p1,11, p2)
print(pages)

url = "https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

print(soup.text)
LM_list = pd.read_csv("c:\\Users\\famille\\Downloads\\lexiqueLM.csv",sep = ';')
LM_positive = [pos.lower() for pos in LM_list['POSITIVE'].dropna(axis=0)]
LM_negative = [pos.lower() for pos in LM_list['NEGATIVE'].dropna(axis=0)]

with io.open("c:\\Users\\famille\\Downloads\\AAL-10k-2016.txt", 'r',encoding='utf8') as file:
    text = soup.text.replace('\n', ' ')

text_LM = nltk.word_tokenize(text)
print(text_LM)
nb_pos = [word for word in text_LM if word in LM_positive]
nb_neg = [word for word in text_LM if word in LM_negative]
if (len(nb_pos)+len(nb_neg)) != 0:
    Sent_LM = ((len(nb_pos)-len(nb_neg))/(len(nb_pos)+len(nb_neg)))
else:
    Sent_LM = 0

print("NB POS : ", len(nb_pos))
print("NB NEG : ", len(nb_neg))
print("SCORE : ", Sent_LM)
# Out:
# ['https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=0&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=100&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=200&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=300&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=400&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=500&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=600&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type=&dateb=&owner=include&start=700&count=100', 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=%s&type
# ...

# %%
'''import sqlite3
fichierDonnees ="c:\\Users\\famille\\Downloads\\test555.sql"
conn =sqlite3.connect(fichierDonnees)
cur =conn.cursor()
cur.execute("CREATE TABLE membres (age INTEGER, nom TEXT, taille REAL)")'''
# Out:
# 'import sqlite3\nfichierDonnees ="c:\\Users\\famille\\Downloads\\test555.sql"\nconn =sqlite3.connect(fichierDonnees)\ncur =conn.cursor()\ncur.execute("CREATE TABLE membres (age INTEGER, nom TEXT, taille REAL)")'

# %%
import sqlite3
conn =sqlite3.connect("c:\\Users\\famille\\Downloads\\test555.sql") 
cur =conn.cursor() 
cur.execute("SELECT * FROM membres")
for l in cur:
    print(l)
list(cur)
data =[(17,"Durand",1.74),(22,"Berger",1.71),(20,"Weber",1.65)] 
for tu in data:
    cur.execute("INSERT INTO membres(age,nom,taille) VALUES(?,?,?)", tu)
# Out:
# (21, 'Dupont', 1.83)
# (15, 'Blumâr', 1.57)
# (18, 'Özémir', 1.69)

# %%
import sqlite3
fichierDonnees ="c:\\Users\\famille\\Downloads\\BD_CIK.sql"
conn =sqlite3.connect(fichierDonnees)
cur =conn.cursor()
#cur.execute("CREATE TABLE membres (Ticker TEXT,CIK TEXT,Date TEXT,Url TEXT,Document TEXT,Nom TEXT)")
cur.execute("INSERT INTO membres(Ticker,CIK,Date,Url,Document,Nom) VALUES('s','ded','Durfrfr','1dzfzf3','h','j')")
cur.execute("SELECT * FROM membres")
conn.commit() 
for l in cur:
    print(l)
# Out:
# ('2', 'e', 'Dupont', '1dc83', 'h', 'j')
# ('s', 'ded', 'Durfrfr', '1dzfzf3', 'h', 'j')
# ('s', 'ded', 'Durfrfr', '1dzfzf3', 'h', 'j')
# ('s', 'ded', 'Durfrfr', '1dzfzf3', 'h', 'j')

# %%
#pip install PyMySQL
import pymysql.cursors
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='loueur',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
i=0
j=0
e = []
e.append(("olivier","bbb"))
e.append(("jean-louis","bhb"))
data = [
  (dataSet.iloc[i,0], "l"),
  (finalAdress[3], "f"),
  ('John', "f"),
]
d=[]
d.append(("olivier","bbb","jjj","ihi","uh","ll"))
d.append(("jean-louis","bhb","hhh","hu","hi","hh"))
for element in CIK_list:
    d.append((dataSet.iloc[i,0],dataSet.iloc[i,1],"drc","bu","l",finalAdress[4]))
    i=i+1
with connection.cursor() as cursor:
        # Create a new record
        #cursor.execute("CREATE TABLE Ticker (Ticker TEXT,CIK TEXT,Date TEXT,Url TEXT,Document TEXT,Nom TEXT)")
        #stmt = "INSERT INTO Ticker(Ticker,CIK,Date,Url,Document,Nom) VALUES (%s,%s,%s,%s,%s)"
        #cursor.executemany(stmt, users)
        stmt = "INSERT INTO Ticker (Ticker,CIK,Date,Url,Document,Nom) VALUES (%s, %s,%s,%s,%s,%s)"
        cursor.executemany(stmt,d )
        #cursor.execute("delete FROM ticker")
       
        #cursor.execute("INSERT INTO Ticker(Ticker,CIK,Date,Url,Document,Nom) VALUES(finalAdress[i],'g','Durfrfr','1dzfzf3','h','j')",finalAdress)
connection.commit()
cur.close() 
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-18-e010b388f9f1> in <module>
#      34         #cursor.execute("INSERT INTO Ticker(Ticker,CIK,Date,Url,Document,Nom) VALUES(finalAdress[i],'g','Durfrfr','1dzfzf3','h','j')",finalAdress)
#      35 connection.commit()
# ---> 36 cur.close()
#      37 conn.close()
#
# ProgrammingError: Cannot operate on a closed database.

# %%
for element in CIK_list:
    print (element)
for element in finalAdress:
    print (element)
# Out:
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# 0000004962
# 0000732712
# 0001489393
# ...

# %%
import pandas as pd
import csv
import numpy as np
from math import log
dataSet= pd.read_csv("c:\\Users\\famille\\Downloads\\DatasetCIK.csv", sep=";")
dataSet["CIK"]=0
dataSet["Date"]=0
dataSet["Document"]=0
dataSet["Url"]=0
i=0
users = []
for element in CIK_list:
    users.append((dataSet.iloc[i,0],"t" ,"k","h","u"))
    dataSet.iloc[i,1]= element
    i=i+1
